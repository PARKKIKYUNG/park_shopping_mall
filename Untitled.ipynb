# %%
import pandas as pd
import numpy as np
import streamlit as st

# %%
df = pd.read_csv("박준형찐.csv").iloc[:,0:4]

# %%
df
# Out:
#       대분류        소분류                                              질의 내용  \
# 0    제품관련  취급방법 및 효과                           bpm정보가 없네요? bpm정보 부탁드립니다
# 1    제품관련  취급방법 및 효과  안녕하세요.. 병풀추출물과 어성초 제품 구매해서 사용 중인데요.. 효과는 잘 모르겠...
# 2    제품관련  취급방법 및 효과  원씽에서 판매하는 추출물은 혹시 일본산 원료가 함유되어 있나요? 방부제 같은 성분들...
# 3    제품관련  취급방법 및 효과             안녕하세요. 병풀 원료함량이 어떻게 되나요? 고형분 함량이 궁금해요.
# 4    제품관련  취급방법 및 효과                     병풀추출물이요 정제수없는100%원액인가요? 몇%인가요?
# ..    ...        ...                                                ...
# 165    행사         헐인  배송비 쿠폰이라니 참 치사한 회사네요 무료배송은 물건가격에서 할인 혜택을 주어야지 ...
# 166    행사         할인                      쿠폰이 왜 적용이 안되나요 쿠폰 적용칸이 아예 없어요
# 167    행사         할인  쿠폰을 다운받았는데 어성초, 병풍, 호호바 이렇게 구매하려보니 쿠폰 적용하는게 없어...
# 168  제품관련  취급방법 및 효과                                     공병 같이시켰는데 안왔어요
# 169  제품관련  취급방법 및 효과                     공병을 주문했어요~ 세척하지 않고 그냥 사용해도 될까요
#
#                                                     답변
# ...
